# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
sns.set_style('darkgrid')
data= pd.read_csv('CC GENERAL.csv')
data.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
# CUST_ID                             8950 non-null object
# BALANCE                             8950 non-null float64
# BALANCE_FREQUENCY                   8950 non-null float64
# PURCHASES                           8950 non-null float64
# ONEOFF_PURCHASES                    8950 non-null float64
# INSTALLMENTS_PURCHASES              8950 non-null float64
# CASH_ADVANCE                        8950 non-null float64
# PURCHASES_FREQUENCY                 8950 non-null float64
# ONEOFF_PURCHASES_FREQUENCY          8950 non-null float64
# PURCHASES_INSTALLMENTS_FREQUENCY    8950 non-null float64
# CASH_ADVANCE_FREQUENCY              8950 non-null float64
# CASH_ADVANCE_TRX                    8950 non-null int64
# PURCHASES_TRX                       8950 non-null int64
# CREDIT_LIMIT                        8949 non-null float64
# ...

# %%
data.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
data.isnull().sum()
#檢查空值
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
del data['CUST_ID']

# %%
data = data.dropna()

# %%
data.isnull().sum()
#y再次檢查空值
# Out:
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
#Correlation 相關係數
corr=data.corr()
corr
# Out:
#                                    BALANCE  BALANCE_FREQUENCY  PURCHASES  \
# BALANCE                           1.000000           0.310140   0.176083
# BALANCE_FREQUENCY                 0.310140           1.000000   0.122635
# PURCHASES                         0.176083           0.122635   1.000000
# ONEOFF_PURCHASES                  0.159985           0.095254   0.916780
# INSTALLMENTS_PURCHASES            0.122109           0.114739   0.679259
# CASH_ADVANCE                      0.495586           0.089036  -0.053760
# PURCHASES_FREQUENCY              -0.088459           0.228158   0.393000
# ONEOFF_PURCHASES_FREQUENCY        0.063832           0.187467   0.497384
# PURCHASES_INSTALLMENTS_FREQUENCY -0.069582           0.184159   0.316025
# CASH_ADVANCE_FREQUENCY            0.445307           0.181132  -0.124863
# CASH_ADVANCE_TRX                  0.382388           0.133265  -0.070277
# PURCHASES_TRX                     0.147887           0.183095   0.688732
# ...

# %%
#把相關係數做成heatplot
plt.subplots(figsize=(15,10))
sns.heatmap(corr, annot=True,cmap="RdGy")

# %%
#把資料標準化
scaler = StandardScaler()
df_scaled = scaler.fit_transform(data)

# %%
df_scaled = pd.DataFrame(df_scaled, columns = list(data))
df_scaled.head()
# Out:
#     BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0 -0.744625          -0.370047  -0.429184         -0.359160
# 1  0.764152           0.067679  -0.473208         -0.359160
# 2  0.426602           0.505405  -0.116413          0.099909
# 3 -0.373910           0.505405  -0.465825         -0.349660
# 4  0.099551           0.505405   0.142062         -0.359160
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0               -0.354826     -0.468655            -0.820769
# 1               -0.458839      2.568556            -1.236139
# 2               -0.458839     -0.468655             1.256077
# 3               -0.458839     -0.468655            -1.028455
# 4                0.994815     -0.468655             0.425339
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                   -0.686280                         -0.717179
# 1                   -0.686280                         -0.926522
# ...

# %%
df_scaled.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count  8.636000e+03       8.636000e+03  8.636000e+03      8.636000e+03
# mean  -2.506872e-18      -5.694740e-15  4.031476e-16     -5.819743e-15
# std    1.000058e+00       1.000058e+00  1.000058e+00      1.000058e+00
# min   -7.641437e-01      -4.309583e+00 -4.732082e-01     -3.591603e-01
# 25%   -6.934691e-01       6.767893e-02 -4.531953e-01     -3.591603e-01
# 50%   -3.265978e-01       5.054046e-01 -2.999696e-01     -3.324445e-01
# 75%    2.405073e-01       5.054046e-01  5.562856e-02     -3.444604e-03
# max    8.323708e+00       5.054046e-01  2.215714e+01      2.384284e+01
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count            8.636000e+03  8.636000e+03         8.636000e+03
# mean             2.643555e-15 -4.485675e-15        -2.187085e-16
# std              1.000058e+00  1.000058e+00         1.000058e+00
# min             -4.588390e-01 -4.686555e-01        -1.236139e+00
# ...

# %%
#用來顯示elbow plot
def elbow_K_means(data, max_k):
    means = []
    inertias = []
    for k in range(1, max_k):
        kmeans = KMeans(n_clusters = k, random_state=42)
        kmeans.fit(data)
        means.append(k)
        inertias.append(kmeans.inertia_)
        
    #Elbow plot
    fig = plt.subplots(figsize = (10, 5))
    plt.plot(means, inertias, 'o-')
    plt.xlabel('Number of clusters')
    plt.ylabel('Inertia')
    plt.grid(True)
    plt.show()
    
#顯示各cluster中心點
def pd_centers(featuresUsed, centers):
    colNames = list(featuresUsed)
    colNames.append('prediction')

    # Zip with a column called 'prediction' (index)
    Z = [np.append(A, index) for index, A in enumerate(centers)]

    # Convert to pandas data frame for plotting
    P = pd.DataFrame(Z, columns=colNames)
    P['prediction'] = P['prediction'].astype(int)
    return P

# %%
elbow_K_means(df_scaled,10)

# %%
kmeans = KMeans(n_clusters = 3,random_state=42)
model = kmeans.fit(df_scaled)
labels = kmeans.labels_ 

kmeans.cluster_centers_.shape
# Out:
# (3, 17)

# %%
#各個cluster的中心點和它是第幾個cluster
centers = model.cluster_centers_
p = pd_centers(list(df_scaled),centers)
p.T
# Out:
#                                          0         1         2
# BALANCE                          -0.369858  0.303323  1.151158
# BALANCE_FREQUENCY                -0.170559  0.419872  0.314053
# PURCHASES                        -0.233503  1.511683 -0.295451
# ONEOFF_PURCHASES                 -0.204575  1.263717 -0.211857
# INSTALLMENTS_PURCHASES           -0.176000  1.251221 -0.309266
# CASH_ADVANCE                     -0.312195 -0.249094  1.362807
# PURCHASES_FREQUENCY              -0.059455  1.133379 -0.654767
# ONEOFF_PURCHASES_FREQUENCY       -0.233650  1.539164 -0.316181
# PURCHASES_INSTALLMENTS_FREQUENCY -0.047989  0.957351 -0.561438
# CASH_ADVANCE_FREQUENCY           -0.336143 -0.364497  1.541906
# CASH_ADVANCE_TRX                 -0.301217 -0.254601  1.325932
# PURCHASES_TRX                    -0.245062  1.667687 -0.372930
# CREDIT_LIMIT                     -0.343113  0.888947  0.597488
# PAYMENTS                         -0.287737  0.824408  0.439942
# ...

# %%
#看每個點各是第幾組
df_cluster = pd.concat([data, pd.DataFrame({'Cluster':labels})], axis = 1)
df_cluster = df_cluster.dropna()
df_cluster.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 4   817.714335           1.000000      16.00             16.00
# 5  1809.828751           1.000000    1333.28              0.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                   95.40      0.000000             0.166667
# 1                    0.00   6442.945483             0.000000
# 2                    0.00      0.000000             1.000000
# 4                    0.00      0.000000             0.083333
# 5                 1333.28      0.000000             0.666667
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
df_cluster['Cluster'].value_counts()
#可以看出各個cluster佔總數的比率
# Out:
# 0.0    5653
# 2.0    1508
# 1.0    1178
# Name: Cluster, dtype: int64

# %%
for i in data.columns:
    plt.figure(figsize=(35,5), facecolor='grey')
    for j in range(3):
        plt.subplot(1,3,j+1)
        cluster = df_cluster[df_cluster['Cluster'] == j]
        cluster[i].hist(bins = 20, color = 'grey', lw = 3)  
        plt.title('{}  \nCluster {}'.format(i,j), fontsize = 12)
ax = plt.axes()
        
plt.show()

# %%
#使用PCA
pca = PCA(n_components = 2)
principal_comp = pca.fit_transform(df_scaled)
principal_comp
# Out:
# array([[-1.69639539, -1.12257963],
#        [-1.21568175,  2.43565343],
#        [ 0.93585381, -0.3852006 ],
#        ...,
#        [-0.93002571, -1.84123783],
#        [-2.35600925, -0.71873618],
#        [-0.59681801, -0.44602958]])

# %%
pca_df = pd.DataFrame(data = principal_comp, columns = ['pca1', 'pca2'])
pca_df.head().style.background_gradient(cmap='RdGy')
# Out:
# <style  type="text/css" >
#     #T_758eff1a_8bf7_11ed_8ab7_00d86185e8c4row0_col0 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_758eff1a_8bf7_11ed_8ab7_00d86185e8c4row0_col1 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_758eff1a_8bf7_11ed_8ab7_00d86185e8c4row1_col0 {
#             background-color:  #cf5246;
#             color:  #000000;
#         }    #T_758eff1a_8bf7_11ed_8ab7_00d86185e8c4row1_col1 {
#             background-color:  #1a1a1a;
#             color:  #f1f1f1;
#         }    #T_758eff1a_8bf7_11ed_8ab7_00d86185e8c4row2_col0 {
#             background-color:  #1a1a1a;
#             color:  #f1f1f1;
#         }    #T_758eff1a_8bf7_11ed_8ab7_00d86185e8c4row2_col1 {
#             background-color:  #d86551;
#             color:  #000000;
#         }    #T_758eff1a_8bf7_11ed_8ab7_00d86185e8c4row3_col0 {
#             background-color:  #7c0722;
#             color:  #f1f1f1;
# ...

# %%
pca_df = pd.concat([pca_df, pd.DataFrame({'Cluster':labels})], axis=1)
pca_df.head()
# Out:
#        pca1      pca2  Cluster
# 0 -1.696395 -1.122580        0
# 1 -1.215682  2.435653        2
# 2  0.935854 -0.385201        0
# 3 -1.614638 -0.724585        0
# 4  0.223701 -0.783607        0

# %%
ppp = pd.DataFrame(pca.components_,columns=list(data),index = ['PCA1','PCA2'])

# %%
ppp.T
# Out:
#                                       PCA1      PCA2
# BALANCE                           0.091986  0.405979
# BALANCE_FREQUENCY                 0.109812  0.127739
# PURCHASES                         0.412151  0.049531
# ONEOFF_PURCHASES                  0.346775  0.069930
# INSTALLMENTS_PURCHASES            0.337056 -0.011481
# CASH_ADVANCE                     -0.030588  0.437248
# PURCHASES_FREQUENCY               0.323665 -0.186582
# ONEOFF_PURCHASES_FREQUENCY        0.294761 -0.014747
# PURCHASES_INSTALLMENTS_FREQUENCY  0.277226 -0.173577
# CASH_ADVANCE_FREQUENCY           -0.099145  0.429996
# CASH_ADVANCE_TRX                 -0.056960  0.416412
# PURCHASES_TRX                     0.391067 -0.011947
# CREDIT_LIMIT                      0.210052  0.243823
# PAYMENTS                          0.263726  0.264181
# MINIMUM_PAYMENTS                  0.059326  0.170416
# PRC_FULL_PAYMENT                  0.130565 -0.195709
# TENURE                            0.077919 -0.004565

# %%
plt.figure(figsize = (20,15), facecolor= 'grey')
ax = sns.scatterplot(x='pca1', y='pca2', hue='Cluster', data=pca_df, palette = ['darkgreen', 'red', '#6b1824'])
plt.title('Cluster: 3', fontsize = 20)
plt.xlabel("PCA1", fontsize= 20)
plt.ylabel("PCA2", fontsize= 20)
plt.show()
